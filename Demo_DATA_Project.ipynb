# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeet2561/13sep_Jeet/blob/main/Demo_DATA_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=sns.load_dataset('tips')
x
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df = pd.DataFrame(x)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df = df.dropna()
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Compare Tipping Behaviour :
#
#
# ---
#
#
#
# *   Between smokers vs non-smokers
# *   Between male vs female
# *   Across Different Days

# %%
x['Tip_percentage'] = x['tip'] / x['total_bill'] * 100
x
# Out:
#      total_bill   tip     sex smoker   day    time  size  Tip_percentage
# 0         16.99  1.01  Female     No   Sun  Dinner     2        5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3       16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3       16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2       13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4       14.680765
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2        9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2       15.974441
#
# [244 rows x 8 columns]

# %%
print("Smoker vs Non-Smoker : \n" ,x.groupby('smoker')['Tip_percentage'].mean())
print("\nMale vs Female : \n" ,x.groupby('sex')['Tip_percentage'].mean())
print("\nAcross Different Days : \n" ,x.groupby('day')['Tip_percentage'].mean())
# Out:
# Smoker vs Non-Smoker :
#  smoker
# Yes    16.319604
# No     15.932846
# Name: Tip_percentage, dtype: float64
#
# Male vs Female :
#  sex
# Male      15.765055
# Female    16.649074
# Name: Tip_percentage, dtype: float64
#
# Across Different Days :
#  day
# Thur    16.127563
# Fri     16.991303
# Sat     15.315172
# Sun     16.689729
# Name: Tip_percentage, dtype: float64
# <ipython-input-21-19fd3a8f292b>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print("Smoker vs Non-Smoker : \n" ,x.groupby('smoker')['Tip_percentage'].mean())
# ...

# %%
sns.boxplot(x='sex',y='Tip_percentage',data=x)
# Out:
# <Axes: xlabel='sex', ylabel='Tip_percentage'>

# %%
sns.barplot(x='smoker',y='Tip_percentage',data=x)
# Out:
# <Axes: xlabel='smoker', ylabel='Tip_percentage'>

# %%
sns.violinplot(x='day',y='Tip_percentage',data=x)
# Out:
# <Axes: xlabel='day', ylabel='Tip_percentage'>
